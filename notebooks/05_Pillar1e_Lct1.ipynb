# %% [markdown]
# # Pillar 1 EDA Lecture 2

# %% [markdown]
# Sat 08 Feb 2025

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
os.chdir(r"C:\Users\willi\OneDrive\Documents\Woolf Institute Data Analytics\Live Class Data Sets")

# %%
# Load the data
df = pd.read_csv("basic_salary2.csv")

# %%
# Display basic info
print(df.info())
print(df.describe())
print("Dimension of the dataset: ", df.shape)

# Visualize data
sns.pairplot(df, hue="Function")
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First_Name  41 non-null     object
#  1   Last_Name   41 non-null     object
#  2   Grade       40 non-null     object
#  3   Location    38 non-null     object
#  4   Function    39 non-null     object
#  5   ba          39 non-null     float64
#  6   ms          37 non-null     float64
# dtypes: float64(2), object(5)
# memory usage: 2.4+ KB
# None
#                  ba            ms
# count     39.000000     37.000000
# mean   17209.743590  11939.054054
# std     4159.515241   3223.018305
# min    10940.000000   2700.000000
# 25%    13785.000000  10450.000000
# 50%    16230.000000  12420.000000
# 75%    19305.000000  14200.000000
# max    29080.000000  16970.000000
# Dimension of the dataset:  (41, 7)

# %%
X = 20
y = 15

# add x and y labels

# %%
X + y
# Out:
# 35

# %%
# Multiply x and y

X * y
# Out:
# 300

# %%
# Print Msg
print("Welcome to Data Analytics")
# Out:
# Welcome to Data Analytics

# %%
print("This is", "session no.",3)
# Out:
# This is session no. 3

# %%
# Using %d to print integer, %f to print float, %s to print string and %x to print hexadecimal
x = 14
print("He is %d yrs old" %x)
# Out:
# He is 14 yrs old

# %%
help(X)
# Out:
# Help on int object:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating-point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
# ...

# %%
x = ("10")
y = 15.3
z = -32.54e100
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'float'>

# %%
x = "Welcome to the Python Wolrd"
x
z = "3948"
z
type(z) 
x = x + ", John"
print(x)
# Out:
# Welcome to the Python Wolrd, John

# %%
x[0]
"w"
x[2:5]
"lco"
len(x)
# Out:
# 33

# %%
K = list[X]
print (K)
# Out:
# list[20]

# %%
a = 1567
a

y=str(a)
y
# Out:
# '1567'

# %%
list1 = ["python", 1998, "list"]

# %%
list1[0]
# Out:
# 'python'

# %%
list2 = ["fruits", "vegetables", "grains", 100]

# %%
len(list2)
# Out:
# 4

# %%
list2[1] = "nuts"

# %%
print(list2)
# Out:
# ['fruits', 'nuts', 'grains', 100]

# %%
list2.append("seeds")
print(list2)
# Out:
# ['fruits', 'nuts', 'grains', 100, 'seeds']

# %%
del list2[1]
print(list2)

list2.remove("grains")
# Out:
# ['fruits', 'grains', 100, 'seeds']

# %%
list2.insert(2, "grains")
print(list2)
# Out:
# ['fruits', 100, 'grains', 'seeds']

# %%
list2.index("grains")
print(list2)
# Out:
# ['fruits', 100, 'grains', 'seeds']

# %%
list3 = [2001, 2004, 2005, 2008, 2010]

# %%
list3.sort()
print(list3)
# Out:
# [2001, 2004, 2005, 2008, 2010]

# %%
tuple1 = ("math", "physics", "chemistry")
print(tuple1)
# Out:
# ('math', 'physics', 'chemistry')

# %%
tuple[0]
# Out:
# tuple[0]

# %%
tuple[0]
tuple[0] = "Mathematics"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 2
#       1 tuple[0]
# ----> 2 tuple[0] = "Mathematics"
#
# TypeError: 'type' object does not support item assignment

# %%
tup1 = ("one", "two", "three")
tup2 = (11,22,44.5)
tup3 = (tup1, tup2)
print(tup3)
print(tup1 + tup2)
# Out:
# (('one', 'two', 'three'), (11, 22, 44.5))
# ('one', 'two', 'three', 11, 22, 44.5)

# %%
dict1 = {"name": "Chenecho", "age": 49, "city": "Chingola"} 
print(dict1)
dict1["name"]
# Out:
# {'name': 'Chenecho', 'age': 49, 'city': 'Chingola'}
# 'Chenecho'

# %%
dict1["School"] = "Mpelembe"
print(dict1)
# Out:
# {'name': 'Chenecho', 'age': 49, 'city': 'Chingola', 'School': 'Mpelembe'}

# %%
dict1.clear()
print(dict1)
# Out:
# {}

# %%
del dict1
print(dict1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 2
#       1 del dict1
# ----> 2 print(dict1)
#
# NameError: name 'dict1' is not defined
